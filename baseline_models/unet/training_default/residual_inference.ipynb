# %%
import numpy as np
from sklearn.metrics import r2_score
import torch
import os, gc
from climsim_utils.data_utils import *
from tqdm import tqdm
from matplotlib import cm

# %%
def edm_sampler(
    net, latents, class_labels=None, randn_like=torch.randn_like,
    num_steps=18, sigma_min=0.002, sigma_max=80, rho=7,
    S_churn=0, S_min=0, S_max=float('inf'), S_noise=1,
):
    # Adjust noise levels based on what's supported by the network.
    #sigma_min = max(sigma_min, net.sigma_min)
    #sigma_max = min(sigma_max, net.sigma_max)

    # Time step discretization.
    step_indices = torch.arange(num_steps, dtype=torch.float64, device=latents.device)
    t_steps = (sigma_max ** (1 / rho) + step_indices / (num_steps - 1) * (sigma_min ** (1 / rho) - sigma_max ** (1 / rho))) ** rho
    t_steps = torch.cat([net.round_sigma(t_steps), torch.zeros_like(t_steps[:1])]) # t_N = 0

    # Main sampling loop.
    x_next = latents.to(torch.float64) * t_steps[0]
    for i, (t_cur, t_next) in enumerate(zip(t_steps[:-1], t_steps[1:])): # 0, ..., N-1
        x_cur = x_next

        # Increase noise temporarily.
        gamma = min(S_churn / num_steps, np.sqrt(2) - 1) if S_min <= t_cur <= S_max else 0
        t_hat = net.round_sigma(t_cur + gamma * t_cur)
        x_hat = x_cur + (t_hat ** 2 - t_cur ** 2).sqrt() * S_noise * randn_like(x_cur)

        # Euler step.
        denoised = net(x_hat, t_hat, class_labels).to(torch.float64)
        d_cur = (x_hat - denoised) / t_hat
        x_next = x_hat + (t_next - t_hat) * d_cur

        # Apply 2nd order correction.
        if i < num_steps - 1:
            denoised = net(x_next, t_next, class_labels).to(torch.float64)
            d_prime = (x_next - denoised) / t_next
            x_next = x_hat + (t_next - t_hat) * (0.5 * d_cur + 0.5 * d_prime)

    return x_next

class StackedRandomGenerator:
    def __init__(self, device, seeds):
        super().__init__()
        self.generators = [torch.Generator(device).manual_seed(int(seed) % (1 << 32)) for seed in seeds]

    def randn(self, size, **kwargs):
        assert size[0] == len(self.generators)
        return torch.stack([torch.randn(size[1:], generator=gen, **kwargs) for gen in self.generators])

    def randn_like(self, input):
        return self.randn(input.shape, dtype=input.dtype, layout=input.layout, device=input.device)

    def randint(self, *args, size, **kwargs):
        assert size[0] == len(self.generators)
        return torch.stack([torch.randint(*args, size=size[1:], generator=gen, **kwargs) for gen in self.generators])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
latents = torch.randn(1,368, 60).to(device)

# %%
from physicsnemo.launch.utils import (
    load_checkpoint,
    save_checkpoint,
    get_checkpoint_dir,
)

diff_path = '/pscratch/sd/k/kfrields/hugging/E3SM-MMF_saved_models/diffusion_models/diff_test/'
net = load_checkpoint(diff_path)
# Out:
# `DistributedManager` not initialized already. Initializing now, but this might lead to unexpected errors
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/modulus/distributed/manager.py:293, in DistributedManager.initialize()
#     292 try:
# --> 293     DistributedManager.initialize_env()
#     294 except TypeError:
#
# File /usr/local/lib/python3.10/dist-packages/modulus/distributed/manager.py:208, in DistributedManager.initialize_env()
#     207 """Setup method using generic initialization"""
# --> 208 rank = int(os.environ.get("RANK"))
#     209 world_size = int(os.environ.get("WORLD_SIZE"))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       1 from physicsnemo.launch.utils import (
#       2     load_checkpoint,
#       3     save_checkpoint,
#       4     get_checkpoint_dir,
#       5 )
#       7 diff_path = '/pscratch/sd/k/kfrields/hugging/E3SM-MMF_saved_models/diffusion_models/diff_test/'
# ----> 8 net = load_checkpoint(diff_path)
#
# File /global/u2/k/kfrields/climsim-kaggle-edition/baseline_models/unet/training_default/physicsnemo/launch/utils/checkpoint.py:432, in load_checkpoint(path, models, optimizer, scheduler, scaler, epoch, metadata_dict, device)
#     427         checkpoint_logging.success(
#     428             f"Loaded model state dictionary {file_name} to device {device}"
#     429         )
#     431 # == Loading training checkpoint ==
# --> 432 checkpoint_filename = _get_checkpoint_filename(path, index=epoch, model_type="pt")
#     433 if not fs.exists(checkpoint_filename):
#     434     checkpoint_logging.warning(
#     435         "Could not find valid checkpoint file, skipping load"
#     436     )
#
# File /global/u2/k/kfrields/climsim-kaggle-edition/baseline_models/unet/training_default/physicsnemo/launch/utils/checkpoint.py:88, in _get_checkpoint_filename(path, base_name, index, saving, model_type)
#      84 if not DistributedManager.is_initialized():
#      85     checkpoint_logging.warning(
#      86         "`DistributedManager` not initialized already. Initializing now, but this might lead to unexpected errors"
#      87     )
# ---> 88     DistributedManager.initialize()
#      89 manager = DistributedManager()
#      90 model_parallel_rank = (
#      91     manager.group_rank("model_parallel")
#      92     if "model_parallel" in manager.group_names
#      93     else 0
#      94 )
#
# File /usr/local/lib/python3.10/dist-packages/modulus/distributed/manager.py:296, in DistributedManager.initialize()
#     294 except TypeError:
#     295     if "SLURM_PROCID" in os.environ:
# --> 296         DistributedManager.initialize_slurm(port)
#     297     elif "OMPI_COMM_WORLD_RANK" in os.environ:
#     298         DistributedManager.initialize_open_mpi(addr, port)
#
# File /usr/local/lib/python3.10/dist-packages/modulus/distributed/manager.py:252, in DistributedManager.initialize_slurm(port)
#     249 local_rank = int(os.environ.get("SLURM_LOCALID"))
#     250 addr = os.environ.get("SLURM_LAUNCH_NODE_IPADDR")
# --> 252 DistributedManager.setup(
#     253     rank=rank,
#     254     world_size=world_size,
#     255     local_rank=local_rank,
#     256     addr=addr,
#     257     port=port,
#     258     backend=DistributedManager.get_available_backend(),
#     259     method="slurm",
#     260 )
#
# File /usr/local/lib/python3.10/dist-packages/modulus/distributed/manager.py:328, in DistributedManager.setup(rank, world_size, local_rank, addr, port, backend, method)
#     317 @staticmethod
#     318 def setup(
#     319     rank=0,
#    (...)
#     325     method="env",
#     326 ):
#     327     """Set up PyTorch distributed process group and update manager attributes"""
# --> 328     os.environ["MASTER_ADDR"] = addr
#     329     os.environ["MASTER_PORT"] = str(port)
#     331     manager = DistributedManager()
#
# File /usr/lib/python3.10/os.py:685, in _Environ.__setitem__(self, key, value)
#     683 def __setitem__(self, key, value):
#     684     key = self.encodekey(key)
# --> 685     value = self.encodevalue(value)
#     686     putenv(key, value)
#     687     self._data[key] = value
#
# File /usr/lib/python3.10/os.py:757, in _createenviron.<locals>.encode(value)
#     755 def encode(value):
#     756     if not isinstance(value, str):
# --> 757         raise TypeError("str expected, not %s" % type(value).__name__)
#     758     return value.encode(encoding, 'surrogateescape')
#
# TypeError: str expected, not NoneType
